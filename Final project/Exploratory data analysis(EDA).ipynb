# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("heart.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
data["chol"].unique()
# Out:
# array([212, 203, 174, 294, 248, 318, 289, 249, 286, 149, 341, 210, 298,
#        204, 308, 266, 244, 211, 185, 223, 208, 252, 209, 307, 233, 319,
#        256, 327, 169, 131, 269, 196, 231, 213, 271, 263, 229, 360, 258,
#        330, 342, 226, 228, 278, 230, 283, 241, 175, 188, 217, 193, 245,
#        232, 299, 288, 197, 315, 215, 164, 326, 207, 177, 257, 255, 187,
#        201, 220, 268, 267, 236, 303, 282, 126, 309, 186, 275, 281, 206,
#        335, 218, 254, 295, 417, 260, 240, 302, 192, 225, 325, 235, 274,
#        234, 182, 167, 172, 321, 300, 199, 564, 157, 304, 222, 184, 354,
#        160, 247, 239, 246, 409, 293, 180, 250, 221, 200, 227, 243, 311,
#        261, 242, 205, 306, 219, 353, 198, 394, 183, 237, 224, 265, 313,
#        340, 259, 270, 216, 264, 276, 322, 214, 273, 253, 176, 284, 305,
#        168, 407, 290, 277, 262, 195, 166, 178, 141], dtype=int64)

# %%
data["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart = data.drop(["ca"],axis=1)

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
corelation = heart.corr()

# %%
sns.pairplot(heart)

# %%
sns.relplot(x= "target", y= "chol", hue= "thal", data=heart )

# %%
sns.relplot(x= "target", y= "chol", hue= "fbs", data=heart )

# %%
sns.relplot(x= "age", y= "sex", hue= "target", data=heart )

# %%
sns.relplot(x= "target", y= "chol", hue= "age", data=heart )

# %%
sns.relplot(x= "thal", y= "chol", hue= "age", data=heart )

# %%
sns.relplot(x= "fbs", y= "target", hue= "age", data=heart )

# %%
sns.relplot(x= "slope", y= "chol", hue= "age", data=heart )

# %%
sns.displot(heart["target"])

# %%
sns.displot(heart["thal"])

# %%
sns.displot(heart["age"])

# %%
sns.displot(heart["thal"])

# %%
sns.displot(heart["fbs"])

# %%
sns.displot(heart["age"])

# %%
sns.displot(heart["sex"])

# %%
sns.catplot(x="sex", kind= "box", data=heart)

# %%
sns.catplot(x="age", kind= "box", data=heart)

# %%
sns.catplot(x="target", kind= "box", data=heart)

# %%
sns.catplot(x="chol", kind= "box", data=heart)

# %%
sns.catplot(x="fbs", kind= "box", data=heart)

# %%
sns.catplot(x="slope", kind= "box", data=heart)
